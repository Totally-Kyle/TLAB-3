# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #get br_final to graph changes through the years

# %%
EDA = pd.read_csv("/Users/sa24/Downloads/weather_api/data/csv/br_final.csv")

# %%
EDA["nonbear_mill_trees"].hist(bins=12)
# Out:
# <Axes: >

# %% [markdown]
# #check the monthly weather to see if it affects coffee production

# %%
sns.lineplot(EDA, x="year", y="million_60kgs_bag", hue="subdivision", marker="o").set_title("Brazil Coffee Harvest")
# Out:
# Text(0.5, 1.0, 'Brazil Coffee Harvest')

# %%
sns.lineplot(EDA, x="year", y="avg_unemp_perc", hue="subdivision", marker="o").set_title("Unemployment rate")
# Out:
# Text(0.5, 1.0, 'Unemployment rate')

# %%
EDA.plot.scatter(x='subdivision', y= 'bear_mill_trees')
# Out:
# <Axes: xlabel='subdivision', ylabel='bear_mill_trees'>

# %% [markdown]
# #see the trees that bear coffee beans based on the subdivision
