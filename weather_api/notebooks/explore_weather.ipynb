# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #get br_final to graph changes through the years

# %%
EDA = pd.read_csv("/Users/sa24/Downloads/weather_api/data/csv/br_final.csv")

# %%
weather = pd.read_csv("/Users/sa24/Downloads/weather_api/data/csv/monthly_median_data.csv")
weather.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'temperature_2m'}>],
#        [<Axes: title={'center': 'relative_humidity_2m'}>,
#         <Axes: title={'center': 'precipitation'}>],
#        [<Axes: title={'center': 'surface_pressure'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# #check the monthly weather to see if it affects coffee production

# %% [markdown]
# sns.lineplot(EDA, x="year", y="million_60kgs_bag", hue="subdivision", marker="o").set_title("Brazil Coffee Harvest")

# %%
#sns.lineplot(EDA, x="year", y="bear_mill_trees", hue="subdivision", marker="o").set_title("Brazil Coffee Trees")
